# %%
# -*- coding: utf-8 -*-
from pyspark.sql import SparkSession

spark = SparkSession \
        .builder \
        .appName("Python Spark SQL Hive") \
        .config("hive.metastore.uris", "thrift://hklpadifr05.hk.standardchartered.com:9083,thrift://hklpadifr06.hk.standardchartered.com:9083") \
        .config("hive.exec.dynamic.partition.mode", "nonstrict") \
        .config("spark.sql.catalogImplementation","hive") \
        .config("spark.sql.hive.convertMetastoreOrc", "false") \
        .enableHiveSupport() \
        .getOrCreate()
            
# Read data using SQL


df = spark.sql("select * from sasdatamart.a_auto_loan limit 2")
#df = spark.sql("select * from a_auto_loan limit 2")
#print(df.show())
df.write.format("csv").mode("overwrite").option("header", "true").save("file:///test/cit/sasdata/ssplice/HiveExport/a_auto_loan.csv")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# An error occurred while calling o744.save.
# : java.lang.AssertionError: assertion failed: No plan for HiveTableRelation `sasdatamart`.`a_auto_loan`, org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe, [a_car_sell_prc#1805, a_cash_bck_amt#1806, a_coe_amt#1807, a_parf_amt#1808, a_veh_prc#1809, a_veh_value#1810, c_car_body_type#1811, c_car_capacity#1812, c_car_off_peak#1813, c_chasis_no#1814, c_deal_no#1815, c_dealer_cd#1816, c_engine_no#1817, c_parf_eligibility#1818, c_regis_city#1819, c_regis_no#1820, c_regis_type#1821, c_valuer#1822, c_veh_cat#1823, c_veh_col#1824, c_veh_make#1825, c_veh_model#1826, d_4th_sch_exp_dte#1827, d_4th_sch_hold_exp_dte#1828, ... 31 more fields], [base_dt#1860, country_cd#1861]
#
# 	at scala.Predef$.assert(Predef.scala:170)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.plan(QueryPlanner.scala:93)
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Python Spark SQL Hive") \
.config("hive.metastore.uris","thrift://hklpadifr05.hk.standardchartered.com:9083,thrift://hklpadifr06.hk.standardchartered.com:9083") \
.config("hive.exec.dynamic.partition.mode","nonstrict") \
.config("spark.sql.catalogImplementation","hive") \
.enableHiveSupport().getOrCreate()

#df=spark.sql("show databases like 's.*'").show()
#print(df)
spark.sql("use sasdatamart")
#spark.sql("show tables").show()
df=spark.sql("select * from MM_EAD_CIC where base_dt <= \"2021-03-31\"")
df.show()
#df.write.format("csv").mode("overwrite").option("header","true").save("hdfs://HKLPADIFR06.hk.standardchartered.com:8020/sasdata/MM_EAD_CIC.csv")
df.write.format("csv").mode("overwrite").option("header","true").save("file:///test/cit/sasdata/ssplice/HiveExport/SparkOutput/")
# Out:
# An error was encountered:
# Invalid status code '404' from http://livy-spark:8998/sessions/11 with error payload: {"msg":"Session '11' not found."}
